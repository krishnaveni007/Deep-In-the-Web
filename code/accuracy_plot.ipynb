# %% [markdown]
# Accuracy for models with extra features: [0.52857143 0.57142857 0.64285714 0.55714286 0.61428571 0.6 0.51428571 0.54285714 0.65714286 0.64285714]
# Average accuracy with extra features 0.5871428571428572
#
# Accuracy for models without extra features: [0.68711656 0.6809816  0.74233129 0.69018405 0.70858896 0.71472393
#  0.68711656 0.68404908 0.66564417 0.68404908]
# Average accuracy without extra features 0.694478527607362

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
models = [0.52857143, 0.57142857, 0.64285714, 0.55714286, 
    0.61428571, 0.6, 0.51428571, 0.54285714, 0.65714286, 0.64285714, 0.5871428571428572]

models_features = [0.68711656, 0.6809816, 0.74233129, 0.69018405,
    0.70858896, 0.71472393, 0.68711656, 0.68404908, 0.66564417, 0.68404908, 0.694478527607362]

# %%
fig, ax = plt.subplots()
width = 0.35

# Create positions for bars
x = np.arange(len(models))

# Create the bar plot
rect1 = ax.bar(x - width/2, models, width, label='with extra features', color='blue')
rect2 = ax.bar(x + width/2, models_features, width, label='without extra features', color='orange')

ax.axvline(x=9.5, color='black', linestyle='--')

# Customize the plot
ax.set_ylabel('Scores')
ax.set_xlabel('Model runs')
ax.set_title('Model Accuracies')
ax.set_xticks([i for i in range(len(models) + 1)])
ax.set_xticklabels(['' for i in range(len(models)-1)] + ['average', ''])
ax.legend(loc='lower left')

# Display the plot
fig.savefig('../final/images/model_bars.png')
